# %%
#import:
import LexExpander

# %%
#create an LexExpander Instance ... 
# we also need an embedding file
# and optionally a steering|starting point: these are some candidates 
# that we initially give as a steering (where to search)

EMBEDDINGFILE = "smd_50k_kv"
LEXICON = "Tiere_minimal.txt"
STARTINGPOINT = ["Elefant", "Nashorn"]

my_expander = LexExpander.LexExpander(  given_embedding_file= EMBEDDINGFILE , 
                                        lexicon_file = LEXICON,
                                        candidates_list = STARTINGPOINT,
                                        # target_folder = ".",
                                        )

# %%
#prepare: this means: load lexicons, embeddings, set stuff ...
my_expander.prepare(verbose=True)
# Out:
# reading in the lexicon ...
# ... done in 0.000s.
# setting up embeddings ...
# loading embeddings
# loading w2v model smd_50k_kv ...
# trying loading with keyedvectors method
# ... done in 0.186s.
#
#             10 iterations
#             1 keep_size
#             4 new_in_lex_topn_to_draw_from
#             1 sample_size
#             2 new_topn_to_draw_from
#             100 result_size
#             3 rec_runs
#             0.5 weak_add_rate
#
#
#
#             self.lexicon_file:	Tiere_minimal.txt
#             embedding_model:	<CachedEmbedding.CachedEmbedding object at 0x7f13436ad4c0>
#             candidates_list:	['Elefant', 'Nashorn']
#
#             target_folder:	.

# %%
#and launch:
my_expander.run()
# Out:
# iterations 10
# rec_runs 3
# we start with run number 1
# in the lexicon we have:
# 20 entries till now...
# in the weak lexicon we have:
# 0 entries till now...
# in the not-to-inlcude-lexicon we have:
# 0 entries till now...
# starting search-cycle for Elefant,Nashorn
# Gorilla already in given LEXICON
# Schildkröte already in given LEXICON
# Schimpanse already in given LEXICON
# Wildschwein already in given LEXICON
# Löwe already in given LEXICON
# Eisbär already in given LEXICON
# Kaninchen already in given LEXICON
# Fledermaus already in given LEXICON
# already in lexicon: 8
# appending 42 new candidates
# ['Affe', 'Giraffe', 'Zebra', 'frei_Wildbahn', 'Tier', 'Raubkatze', 'Krokodil', 'Zoo', 'Jungtier', 'Gehege', 'Raubtier', 'Reptil', 'Papagei', 'Tierpark', 'Menschenaffe', 'Zürcher_Zoo', 'Pinguin', 'Artgenosse', 'Wilderer', 'Wildtier', 'Zoo_Zürich', 'wild_Tier', 'Kamel', 'Büffel', 'Eichhörnchen', 'Känguru', 'Esel', 'Tierart', 'Hase', 'Tiger', 'Tierpfleger', 'Männchen', 'Katze', 'Ziege', 'Greifvogel', 'Säugetier', 'Reh', 'ausgestopft', 'Weibchen', 'Eidechse', 'Frosch', 'erlegen']
# ************************************************************
# starting search-cycle for Wildschwein,Giraffe
# Hirsch already in given LEXICON
# Schildkröte already in given LEXICON
# Steinbock already in given LEXICON
# Kaninchen already in given LEXICON
# Braunbär already in given LEXICON
# Eisbär already in given LEXICON
# Gans already in given LEXICON
# already in lexicon: 7
# appending 43 new candidates
# ['Reh', 'Elefant', 'Luch', 'Hase', 'Raubtier', 'Nashorn', 'Raubkatze', 'Eichhörnchen', 'Tier', 'Wildtier', 'Gehege', 'Gämse', 'Jungtier', 'Ente', 'erlegen', 'Eidechse', 'Zebra', 'Luchs', 'Elch', 'Affe', 'Krähe', 'Büffel', 'wild_Tier', 'Artgenosse', 'Wildhüter', 'Wildkatze', 'Pinguin', 'frei_Wildbahn', 'Ziege', 'Greifvogel', 'Schaf', 'Känguru', 'Krokodil', 'Murmeltier', 'Fuchs', 'Kadaver', 'Igel', 'Katze', 'Reptil', 'Taube', 'Storch', 'fressen', 'Eule']
# ************************************************************
# starting search-cycle for Steinbock,Elefant
# Schildkröte already in given LEXICON
# Wildschwein already in given LEXICON
# Hirsch already in given LEXICON
# Löwe already in given LEXICON
# Braunbär already in given LEXICON
# Gorilla already in given LEXICON
# Eisbär already in given LEXICON
# Bartgeier already in given LEXICON
# Wolf already in given LEXICON
# Kaninchen already in given LEXICON
# already in lexicon: 10
# appending 40 new candidates
# ['Giraffe', 'Nashorn', 'Gämse', 'Tier', 'Raubtier', 'frei_Wildbahn', 'Reh', 'Luch', 'Affe', 'Raubkatze', 'Hase', 'Jungtier', 'Zebra', 'Wildtier', 'Stier', 'Eichhörnchen', 'Gehege', 'Krokodil', 'Wildkatze', 'Reptil', 'Zürcher_Zoo', 'Murmeltier', 'Büffel', 'Eidechse', 'Luchs', 'erlegen', 'Tierpark', 'Kamel', 'Pinguin', 'wild_Tier', 'Zoo_Zürich', 'Greifvogel', 'Artgenosse', 'Widder', 'Männchen', 'Schaf', 'Papagei', 'Zoo', 'Ziege', 'Weibchen']
# ************************************************************
# starting search-cycle for Schildkröte,Giraffe
# Kaninchen already in given LEXICON
# Gorilla already in given LEXICON
# Eisbär already in given LEXICON
# Wildschwein already in given LEXICON
# Steinbock already in given LEXICON
# Fledermaus already in given LEXICON
# Gans already in given LEXICON
# already in lexicon: 7
# appending 43 new candidates
# ['Elefant', 'Krokodil', 'Eidechse', 'Nashorn', 'Pinguin', 'Reptil', 'Affe', 'Eichhörnchen', 'Ente', 'Papagei', 'Raubkatze', 'Hase', 'Frosch', 'Tier', 'Zebra', 'Känguru', 'Artgenosse', 'Meerschweinchen', 'Katze', 'Gehege', 'Jungtier', 'Drache', 'Taube', 'frei_Wildbahn', 'Eule', 'Hai', 'Tierchen', 'Aquarium', 'Büffel', 'Fisch', 'Raubtier', 'ausgestopft', 'Kadaver', 'Küken', 'Kamel', 'Insekt', 'Säugetier', 'Männchen', 'Luch', 'Reh', 'Schnecke', 'Käfig', 'Rüssel']
# ************************************************************
# starting search-cycle for Gorilla,Elefant
# Schimpanse already in given LEXICON
# Schildkröte already in given LEXICON
# Eisbär already in given LEXICON
# Löwe already in given LEXICON
# Fledermaus already in given LEXICON
# Wildschwein already in given LEXICON
# Kaninchen already in given LEXICON
# already in lexicon: 7
# appending 43 new candidates
# ['Affe', 'Nashorn', 'Menschenaffe', 'Tier', 'Zoo', 'Giraffe', 'Krokodil', 'Zebra', 'Raubkatze', 'frei_Wildbahn', 'Zürcher_Zoo', 'Gehege', 'Artgenosse', 'Zoo_Zürich', 'Raubtier', 'Jungtier', 'Pinguin', 'Reptil', 'Männchen', 'Papagei', 'Tierpark', 'Säugetier', 'wild_Tier', 'Weibchen', 'Kamel', 'Ratte', 'Känguru', 'Wildtier', 'Büffel', 'Wildkatze', 'Tierart', 'Tierpfleger', 'Hai', 'Esel', 'Katze', 'Eichhörnchen', 'Frosch', 'Rüssel', 'tierisch', 'Tiger', 'Wilderer', 'Insekt', 'Tierchen']
# ************************************************************
# starting search-cycle for Schildkröte,Affe
# Gorilla already in given LEXICON
# Schimpanse already in given LEXICON
# Kaninchen already in given LEXICON
# Fledermaus already in given LEXICON
# Huhn already in given LEXICON
# already in lexicon: 5
# appending 45 new candidates
# ['Elefant', 'Tier', 'Papagei', 'Reptil', 'Krokodil', 'Artgenosse', 'Ratte', 'Eidechse', 'Frosch', 'Säugetier', 'Katze', 'Menschenaffe', 'Insekt', 'Nashorn', 'Pinguin', 'Eichhörnchen', 'Meerschweinchen', 'Männchen', 'Maus', 'Ente', 'Tierchen', 'Raubkatze', 'frei_Wildbahn', 'Käfig', 'Taube', 'Giraffe', 'Nager', 'Raubtier', 'Spinne', 'Känguru', 'Haustier', 'Hai', 'Jungtier', 'Schnecke', 'Hamster', 'Ameise', 'Eule', 'tierisch', 'Hase', 'Krähe', 'Hund', 'Schwein', 'Weibchen', 'Fisch', 'Kadaver']
# ************************************************************
# starting search-cycle for Gorilla,Tier
# Schimpanse already in given LEXICON
# Schildkröte already in given LEXICON
# Wildschwein already in given LEXICON
# Fledermaus already in given LEXICON
# Kaninchen already in given LEXICON
# Huhn already in given LEXICON
# Eisbär already in given LEXICON
# already in lexicon: 7
# appending 43 new candidates
# ['Affe', 'Elefant', 'Menschenaffe', 'Artgenosse', 'Raubtier', 'Säugetier', 'Jungtier', 'Nashorn', 'Wildtier', 'Reptil', 'Raubkatze', 'Tierart', 'Männchen', 'frei_Wildbahn', 'Weibchen', 'Gehege', 'Hund', 'Zoo', 'Haustier', 'Ratte', 'Katze', 'Lebewesen', 'Insekt', 'Nager', 'Kadaver', 'wild_Tier', 'Schwein', 'tierisch', 'Tierchen', 'Population', 'Wildkatze', 'Schaf', 'Zoo_Zürich', 'Nutztier', 'Pinguin', 'Ziege', 'Maus', 'Krokodil', 'Zürcher_Zoo', 'Papagei', 'Aufzucht', 'Futter', 'Tierpark']
# ************************************************************
# starting search-cycle for Fledermaus,Elefant
# Schildkröte already in given LEXICON
# Gorilla already in given LEXICON
# Wildschwein already in given LEXICON
# Schimpanse already in given LEXICON
# already in lexicon: 4
# appending 46 new candidates
# ['Affe', 'Tier', 'Insekt', 'Nashorn', 'Artgenosse', 'Reptil', 'Frosch', 'Eichhörnchen', 'Greifvogel', 'Papagei', 'Ratte', 'Männchen', 'frei_Wildbahn', 'Krokodil', 'Säugetier', 'Giraffe', 'Krähe', 'Taube', 'Pinguin', 'Storch', 'Eidechse', 'Raubkatze', 'Vogel', 'Jungtier', 'Spinne', 'Raubtier', 'Mücke', 'Igel', 'Eule', 'Tierchen', 'Wildtier', 'Ameise', 'fressen', 'Weibchen', 'Singvogel', 'Jungvogel', 'Tierart', 'Zoo', 'Katze', 'Zebra', 'Ente', 'Hase', 'Schnecke', 'Wildkatze', 'Gehege', 'Vogelart']
# ************************************************************
# starting search-cycle for Gorilla,Tier
# Schimpanse already in given LEXICON
# Schildkröte already in given LEXICON
# Wildschwein already in given LEXICON
# Fledermaus already in given LEXICON
# Kaninchen already in given LEXICON
# Huhn already in given LEXICON
# Eisbär already in given LEXICON
# already in lexicon: 7
# appending 43 new candidates
# ['Affe', 'Elefant', 'Menschenaffe', 'Artgenosse', 'Raubtier', 'Säugetier', 'Jungtier', 'Nashorn', 'Wildtier', 'Reptil', 'Raubkatze', 'Tierart', 'Männchen', 'frei_Wildbahn', 'Weibchen', 'Gehege', 'Hund', 'Zoo', 'Haustier', 'Ratte', 'Katze', 'Lebewesen', 'Insekt', 'Nager', 'Kadaver', 'wild_Tier', 'Schwein', 'tierisch', 'Tierchen', 'Population', 'Wildkatze', 'Schaf', 'Zoo_Zürich', 'Nutztier', 'Pinguin', 'Ziege', 'Maus', 'Krokodil', 'Zürcher_Zoo', 'Papagei', 'Aufzucht', 'Futter', 'Tierpark']
# ************************************************************
# starting search-cycle for Fledermaus,Affe
# Schimpanse already in given LEXICON
# Gorilla already in given LEXICON
# Schildkröte already in given LEXICON
# already in lexicon: 3
# appending 47 new candidates
# ['Insekt', 'Ratte', 'Tier', 'Artgenosse', 'Elefant', 'Säugetier', 'Männchen', 'Maus', 'Frosch', 'Krähe', 'Papagei', 'Spinne', 'Eichhörnchen', 'Taube', 'Eidechse', 'Reptil', 'Eule', 'Ameise', 'Tierchen', 'Raubtier', 'Singvogel', 'Menschenaffe', 'Nager', 'Mücke', 'Weibchen', 'Greifvogel', 'Nashorn', 'Storch', 'frei_Wildbahn', 'Tierart', 'Raubkatze', 'Jungtier', 'Vogel', 'Krokodil', 'fressen', 'Katze', 'Pinguin', 'Igel', 'Biene', 'Jungvogel', 'wild_Tier', 'tierisch', 'Giraffe', 'Schnecke', 'Amsel', 'Wurm', 'Käfig']
# ************************************************************
#
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
#
# run 1- iteration 1: candidates (seed words) were: ['Elefant', 'Nashorn']
# new: ['Affe', 'Giraffe', 'Zebra', 'frei_Wildbahn', 'Tier', 'Raubkatze', 'Krokodil', 'Zoo', 'Jungtier', 'Gehege', 'Raubtier', 'Reptil', 'Papagei', 'Tierpark', 'Menschenaffe', 'Zürcher_Zoo', 'Pinguin', 'Artgenosse', 'Wilderer', 'Wildtier', 'Zoo_Zürich', 'wild_Tier', 'Kamel', 'Büffel', 'Eichhörnchen', 'Känguru', 'Esel', 'Tierart', 'Hase', 'Tiger', 'Tierpfleger', 'Männchen', 'Katze', 'Ziege', 'Greifvogel', 'Säugetier', 'Reh', 'ausgestopft', 'Weibchen', 'Eidechse', 'Frosch', 'erlegen']
# already in list this time: ['Gorilla', 'Schildkröte', 'Schimpanse', 'Wildschwein', 'Löwe', 'Eisbär', 'Kaninchen', 'Fledermaus']
# -----
# run 1- iteration 2: candidates (seed words) were: ['Wildschwein', 'Giraffe']
# new: ['Reh', 'Elefant', 'Luch', 'Hase', 'Raubtier', 'Nashorn', 'Raubkatze', 'Eichhörnchen', 'Tier', 'Wildtier', 'Gehege', 'Gämse', 'Jungtier', 'Ente', 'erlegen', 'Eidechse', 'Zebra', 'Luchs', 'Elch', 'Affe', 'Krähe', 'Büffel', 'wild_Tier', 'Artgenosse', 'Wildhüter', 'Wildkatze', 'Pinguin', 'frei_Wildbahn', 'Ziege', 'Greifvogel', 'Schaf', 'Känguru', 'Krokodil', 'Murmeltier', 'Fuchs', 'Kadaver', 'Igel', 'Katze', 'Reptil', 'Taube', 'Storch', 'fressen', 'Eule']
# already in list this time: ['Hirsch', 'Schildkröte', 'Steinbock', 'Kaninchen', 'Braunbär', 'Eisbär', 'Gans']
# -----
# run 1- iteration 3: candidates (seed words) were: ['Steinbock', 'Elefant']
# new: ['Giraffe', 'Nashorn', 'Gämse', 'Tier', 'Raubtier', 'frei_Wildbahn', 'Reh', 'Luch', 'Affe', 'Raubkatze', 'Hase', 'Jungtier', 'Zebra', 'Wildtier', 'Stier', 'Eichhörnchen', 'Gehege', 'Krokodil', 'Wildkatze', 'Reptil', 'Zürcher_Zoo', 'Murmeltier', 'Büffel', 'Eidechse', 'Luchs', 'erlegen', 'Tierpark', 'Kamel', 'Pinguin', 'wild_Tier', 'Zoo_Zürich', 'Greifvogel', 'Artgenosse', 'Widder', 'Männchen', 'Schaf', 'Papagei', 'Zoo', 'Ziege', 'Weibchen']
# already in list this time: ['Schildkröte', 'Wildschwein', 'Hirsch', 'Löwe', 'Braunbär', 'Gorilla', 'Eisbär', 'Bartgeier', 'Wolf', 'Kaninchen']
# -----
# run 1- iteration 4: candidates (seed words) were: ['Schildkröte', 'Giraffe']
# new: ['Elefant', 'Krokodil', 'Eidechse', 'Nashorn', 'Pinguin', 'Reptil', 'Affe', 'Eichhörnchen', 'Ente', 'Papagei', 'Raubkatze', 'Hase', 'Frosch', 'Tier', 'Zebra', 'Känguru', 'Artgenosse', 'Meerschweinchen', 'Katze', 'Gehege', 'Jungtier', 'Drache', 'Taube', 'frei_Wildbahn', 'Eule', 'Hai', 'Tierchen', 'Aquarium', 'Büffel', 'Fisch', 'Raubtier', 'ausgestopft', 'Kadaver', 'Küken', 'Kamel', 'Insekt', 'Säugetier', 'Männchen', 'Luch', 'Reh', 'Schnecke', 'Käfig', 'Rüssel']
# already in list this time: ['Kaninchen', 'Gorilla', 'Eisbär', 'Wildschwein', 'Steinbock', 'Fledermaus', 'Gans']
# -----
# run 1- iteration 5: candidates (seed words) were: ['Gorilla', 'Elefant']
# new: ['Affe', 'Nashorn', 'Menschenaffe', 'Tier', 'Zoo', 'Giraffe', 'Krokodil', 'Zebra', 'Raubkatze', 'frei_Wildbahn', 'Zürcher_Zoo', 'Gehege', 'Artgenosse', 'Zoo_Zürich', 'Raubtier', 'Jungtier', 'Pinguin', 'Reptil', 'Männchen', 'Papagei', 'Tierpark', 'Säugetier', 'wild_Tier', 'Weibchen', 'Kamel', 'Ratte', 'Känguru', 'Wildtier', 'Büffel', 'Wildkatze', 'Tierart', 'Tierpfleger', 'Hai', 'Esel', 'Katze', 'Eichhörnchen', 'Frosch', 'Rüssel', 'tierisch', 'Tiger', 'Wilderer', 'Insekt', 'Tierchen']
# already in list this time: ['Schimpanse', 'Schildkröte', 'Eisbär', 'Löwe', 'Fledermaus', 'Wildschwein', 'Kaninchen']
# -----
# run 1- iteration 6: candidates (seed words) were: ['Schildkröte', 'Affe']
# new: ['Elefant', 'Tier', 'Papagei', 'Reptil', 'Krokodil', 'Artgenosse', 'Ratte', 'Eidechse', 'Frosch', 'Säugetier', 'Katze', 'Menschenaffe', 'Insekt', 'Nashorn', 'Pinguin', 'Eichhörnchen', 'Meerschweinchen', 'Männchen', 'Maus', 'Ente', 'Tierchen', 'Raubkatze', 'frei_Wildbahn', 'Käfig', 'Taube', 'Giraffe', 'Nager', 'Raubtier', 'Spinne', 'Känguru', 'Haustier', 'Hai', 'Jungtier', 'Schnecke', 'Hamster', 'Ameise', 'Eule', 'tierisch', 'Hase', 'Krähe', 'Hund', 'Schwein', 'Weibchen', 'Fisch', 'Kadaver']
# already in list this time: ['Gorilla', 'Schimpanse', 'Kaninchen', 'Fledermaus', 'Huhn']
# -----
# run 1- iteration 7: candidates (seed words) were: ['Gorilla', 'Tier']
# new: ['Affe', 'Elefant', 'Menschenaffe', 'Artgenosse', 'Raubtier', 'Säugetier', 'Jungtier', 'Nashorn', 'Wildtier', 'Reptil', 'Raubkatze', 'Tierart', 'Männchen', 'frei_Wildbahn', 'Weibchen', 'Gehege', 'Hund', 'Zoo', 'Haustier', 'Ratte', 'Katze', 'Lebewesen', 'Insekt', 'Nager', 'Kadaver', 'wild_Tier', 'Schwein', 'tierisch', 'Tierchen', 'Population', 'Wildkatze', 'Schaf', 'Zoo_Zürich', 'Nutztier', 'Pinguin', 'Ziege', 'Maus', 'Krokodil', 'Zürcher_Zoo', 'Papagei', 'Aufzucht', 'Futter', 'Tierpark']
# already in list this time: ['Schimpanse', 'Schildkröte', 'Wildschwein', 'Fledermaus', 'Kaninchen', 'Huhn', 'Eisbär']
# -----
# run 1- iteration 8: candidates (seed words) were: ['Fledermaus', 'Elefant']
# new: ['Affe', 'Tier', 'Insekt', 'Nashorn', 'Artgenosse', 'Reptil', 'Frosch', 'Eichhörnchen', 'Greifvogel', 'Papagei', 'Ratte', 'Männchen', 'frei_Wildbahn', 'Krokodil', 'Säugetier', 'Giraffe', 'Krähe', 'Taube', 'Pinguin', 'Storch', 'Eidechse', 'Raubkatze', 'Vogel', 'Jungtier', 'Spinne', 'Raubtier', 'Mücke', 'Igel', 'Eule', 'Tierchen', 'Wildtier', 'Ameise', 'fressen', 'Weibchen', 'Singvogel', 'Jungvogel', 'Tierart', 'Zoo', 'Katze', 'Zebra', 'Ente', 'Hase', 'Schnecke', 'Wildkatze', 'Gehege', 'Vogelart']
# already in list this time: ['Schildkröte', 'Gorilla', 'Wildschwein', 'Schimpanse']
# -----
# run 1- iteration 9: candidates (seed words) were: ['Gorilla', 'Tier']
# new: ['Affe', 'Elefant', 'Menschenaffe', 'Artgenosse', 'Raubtier', 'Säugetier', 'Jungtier', 'Nashorn', 'Wildtier', 'Reptil', 'Raubkatze', 'Tierart', 'Männchen', 'frei_Wildbahn', 'Weibchen', 'Gehege', 'Hund', 'Zoo', 'Haustier', 'Ratte', 'Katze', 'Lebewesen', 'Insekt', 'Nager', 'Kadaver', 'wild_Tier', 'Schwein', 'tierisch', 'Tierchen', 'Population', 'Wildkatze', 'Schaf', 'Zoo_Zürich', 'Nutztier', 'Pinguin', 'Ziege', 'Maus', 'Krokodil', 'Zürcher_Zoo', 'Papagei', 'Aufzucht', 'Futter', 'Tierpark']
# already in list this time: ['Schimpanse', 'Schildkröte', 'Wildschwein', 'Fledermaus', 'Kaninchen', 'Huhn', 'Eisbär']
# -----
# run 1- iteration 10: candidates (seed words) were: ['Fledermaus', 'Affe']
# new: ['Insekt', 'Ratte', 'Tier', 'Artgenosse', 'Elefant', 'Säugetier', 'Männchen', 'Maus', 'Frosch', 'Krähe', 'Papagei', 'Spinne', 'Eichhörnchen', 'Taube', 'Eidechse', 'Reptil', 'Eule', 'Ameise', 'Tierchen', 'Raubtier', 'Singvogel', 'Menschenaffe', 'Nager', 'Mücke', 'Weibchen', 'Greifvogel', 'Nashorn', 'Storch', 'frei_Wildbahn', 'Tierart', 'Raubkatze', 'Jungtier', 'Vogel', 'Krokodil', 'fressen', 'Katze', 'Pinguin', 'Igel', 'Biene', 'Jungvogel', 'wild_Tier', 'tierisch', 'Giraffe', 'Schnecke', 'Amsel', 'Wurm', 'Käfig']
# already in list this time: ['Schimpanse', 'Gorilla', 'Schildkröte']
# -----
#
# ************************************************************
#
# we have 97 candidates ...
# giving here top 97:
# frei_Wildbahn:::10	Raubkatze:::10	Krokodil:::10	Jungtier:::10	Raubtier:::10	Reptil:::10	Pinguin:::10	Artgenosse:::10	Papagei:::9	Männchen:::9	Katze:::9	Nashorn:::9	Affe:::8	Tier:::8	Gehege:::8	Eichhörnchen:::8	Säugetier:::8	Weibchen:::8	Wildtier:::7	wild_Tier:::7	Eidechse:::7	Tierchen:::7	Insekt:::7	Giraffe:::6	Zebra:::6	Zoo:::6	Menschenaffe:::6	Tierart:::6	Hase:::6	Frosch:::6	Elefant:::6	Wildkatze:::6	Ratte:::6	Tierpark:::5	Zürcher_Zoo:::5	Zoo_Zürich:::5	Büffel:::5	Känguru:::5	Ziege:::5	Greifvogel:::5	Kadaver:::5	Taube:::5	Eule:::5	tierisch:::5	Kamel:::4	Reh:::4	Ente:::4	Krähe:::4	Schaf:::4	Schnecke:::4	Maus:::4	Nager:::4	erlegen:::3	Luch:::3	Igel:::3	Storch:::3	fressen:::3	Hai:::3	Käfig:::3	Spinne:::3	Haustier:::3	Ameise:::3	Hund:::3	Schwein:::3	Wilderer:::2	Esel:::2	Tiger:::2	Tierpfleger:::2	ausgestopft:::2	Gämse:::2	Luchs:::2	Murmeltier:::2	Meerschweinchen:::2	Fisch:::2	Rüssel:::2	Lebewesen:::2	Population:::2	Nutztier:::2	Aufzucht:::2	Futter:::2	Vogel:::2	Mücke:::2	Singvogel:::2	Jungvogel:::2	Elch:::1	Wildhüter:::1	Fuchs:::1	Stier:::1	Widder:::1	Drache:::1	Aquarium:::1	Küken:::1	Hamster:::1	Vogelart:::1	Biene:::1	Amsel:::1	Wurm:::1
#
# ---tendency-check for new candidates:
#
#
# for frei_Wildbahn:
# lex_in_simple (% of words in lex) = 0.16666666666666666
# lex_lh = 48
# unknown_lh = 417
# lex_lh_perc = 0.1032258064516129
# unknown_lh_perc = 0.896774193548387
# ### adding the WEAK frei_Wildbahn to TEMPlex! ###
# frei_Wildbahn:::10	0.17	0.10	48	0.90	417	Braunbär,Schildkröte,Wolf,Schimpanse,Bartgeier	--vs.--	Elefant,Raubkatze,Jungtier,Raubtier,Tier	--> weak NEW
#
# for Raubkatze:
# lex_in_simple (% of words in lex) = 0.16666666666666666
# lex_lh = 84.5
# unknown_lh = 366
# lex_lh_perc = 0.18756936736958935
# unknown_lh_perc = 0.8124306326304107
# ### adding the WEAK Raubkatze to TEMPlex! ###
# Raubkatze:::10	0.17	0.19	84.5	0.81	366	frei_Wildbahn,Wildschwein,Schildkröte,Braunbär,Gorilla	--vs.--	Raubtier,Nashorn,Jungtier,Wildkatze,Elefant	--> weak NEW
#
# for Krokodil:
# lex_in_simple (% of words in lex) = 0.1
# lex_lh = 52.0
# unknown_lh = 404
# lex_lh_perc = 0.11403508771929824
# unknown_lh_perc = 0.8859649122807017
# ### adding the WEAK Krokodil to TEMPlex! ###
# Krokodil:::10	0.10	0.11	52.0	0.89	404	Schildkröte,Raubkatze,Gorilla	--vs.--	Elefant,Reptil,Affe,Papagei,Hai	--> weak NEW
#
# for Jungtier:
# lex_in_simple (% of words in lex) = 0.16666666666666666
# lex_lh = 41.5
# unknown_lh = 402
# lex_lh_perc = 0.0935738444193912
# unknown_lh_perc = 0.9064261555806088
# ### adding the WEAK Jungtier to TEMPlex! ###
# Jungtier:::10	0.17	0.09	41.5	0.91	402	frei_Wildbahn,Raubkatze,Braunbär,Wildschwein,Bartgeier	--vs.--	Weibchen,Jungvogel,Männchen,Tier,Gehege	--> weak NEW
#
# for Raubtier:
# lex_in_simple (% of words in lex) = 0.23333333333333334
# lex_lh = 114.0
# unknown_lh = 322
# lex_lh_perc = 0.26146788990825687
# unknown_lh_perc = 0.7385321100917431
# ### adding the WEAK Raubtier to TEMPlex! ###
# Raubtier:::10	0.23	0.26	114.0	0.74	322	Wolf,Raubkatze,Braunbär,Wildschwein,frei_Wildbahn	--vs.--	Wildtier,Tier,Luch,Luchs,wild_Tier	--> weak NEW
#
# for Reptil:
# lex_in_simple (% of words in lex) = 0.2
# lex_lh = 67.5
# unknown_lh = 365
# lex_lh_perc = 0.15606936416184972
# unknown_lh_perc = 0.8439306358381503
# ### adding the WEAK Reptil to TEMPlex! ###
# Reptil:::10	0.20	0.16	67.5	0.84	365	Schildkröte,Raubkatze,Krokodil,Raubtier,Jungtier	--vs.--	Insekt,Tier,Säugetier,Amphibie,Tierart	--> weak NEW
#
# for Pinguin:
# lex_in_simple (% of words in lex) = 0.26666666666666666
# lex_lh = 93.5
# unknown_lh = 346
# lex_lh_perc = 0.21274175199089876
# unknown_lh_perc = 0.7872582480091013
# ### adding the WEAK Pinguin to TEMPlex! ###
# Pinguin:::10	0.27	0.21	93.5	0.79	346	Eisbär,Schildkröte,Krokodil,Raubtier,Gorilla	--vs.--	Elefant,Giraffe,Frosch,Affe,Hai	--> weak NEW
# for Artgenosse:
# lex_in_simple (% of words in lex) = 0.26666666666666666
# lex_lh = 100.0
# unknown_lh = 312
# lex_lh_perc = 0.24271844660194175
# unknown_lh_perc = 0.7572815533980582
# ### adding the WEAK Artgenosse to TEMPlex! ###
# Artgenosse:::10	0.27	0.24	100.0	0.76	312	Jungtier,Raubtier,Schimpanse,Reptil,frei_Wildbahn	--vs.--	Tier,Weibchen,Männchen,Affe,Insekt	--> weak NEW
#
# for Papagei:
# lex_in_simple (% of words in lex) = 0.23333333333333334
# lex_lh = 90.5
# unknown_lh = 338
# lex_lh_perc = 0.21120186697782964
# unknown_lh_perc = 0.7887981330221704
# ### adding the WEAK Papagei to TEMPlex! ###
# Papagei:::9	0.23	0.21	90.5	0.79	338	Schildkröte,Krokodil,Pinguin,Huhn,Artgenosse	--vs.--	Affe,Elefant,Katze,Ente,Meerschweinchen	--> weak NEW
#
# for Männchen:
# lex_in_simple (% of words in lex) = 0.26666666666666666
# lex_lh = 98.5
# unknown_lh = 320
# lex_lh_perc = 0.23536439665471923
# unknown_lh_perc = 0.7646356033452808
# ### adding the WEAK Männchen to TEMPlex! ###
# Männchen:::9	0.27	0.24	98.5	0.76	320	Jungtier,Artgenosse,Fledermaus,Reptil,Schimpanse	--vs.--	Weibchen,Jungvogel,Affe,Säugetier,Insekt	--> weak NEW
#
# for Katze:
# lex_in_simple (% of words in lex) = 0.13333333333333333
# lex_lh = 71.0
# unknown_lh = 390
# lex_lh_perc = 0.1540130151843818
# unknown_lh_perc = 0.8459869848156182
# ### adding the WEAK Katze to TEMPlex! ###
# Katze:::9	0.13	0.15	71.0	0.85	390	Kaninchen,Huhn,Schildkröte,Papagei	--vs.--	Hund,Büsi,Haustier,Meerschweinchen,Tier	--> weak NEW
#
# for Nashorn:
# lex_in_simple (% of words in lex) = 0.4666666666666667
# lex_lh = 139.5
# unknown_lh = 263
# lex_lh_perc = 0.34658385093167704
# unknown_lh_perc = 0.653416149068323
# ### adding the WEAK Nashorn to TEMPlex! ###
# Nashorn:::9	0.47	0.35	139.5	0.65	263	Raubkatze,Gorilla,frei_Wildbahn,Schildkröte,Krokodil	--vs.--	Elefant,Giraffe,Wilderer,Affe,Zebra	--> weak NEW
#
# for Affe:
# lex_in_simple (% of words in lex) = 0.43333333333333335
# lex_lh = 146.0
# unknown_lh = 255
# lex_lh_perc = 0.3640897755610973
# unknown_lh_perc = 0.6359102244389028
# ### adding the WEAK Affe to TEMPlex! ###
# Affe:::8	0.43	0.36	146.0	0.64	255	Schimpanse,Gorilla,Artgenosse,Papagei,Männchen	--vs.--	Elefant,Ratte,Maus,Tier,Menschenaffe	--> weak NEW
#
# for Tier:
# lex_in_simple (% of words in lex) = 0.3
# lex_lh = 84.0
# unknown_lh = 307
# lex_lh_perc = 0.21483375959079284
# unknown_lh_perc = 0.7851662404092071
# ### adding the WEAK Tier to TEMPlex! ###
# Tier:::8	0.30	0.21	84.0	0.79	307	Artgenosse,Raubtier,Reptil,Katze,Jungtier	--vs.--	Wildtier,Hund,Haustier,Nutztier,Säugetier	--> weak NEW
#
# for Gehege:
# lex_in_simple (% of words in lex) = 0.43333333333333335
# lex_lh = 113.0
# unknown_lh = 281
# lex_lh_perc = 0.2868020304568528
# unknown_lh_perc = 0.7131979695431472
# ### adding the WEAK Gehege to TEMPlex! ###
# Gehege:::8	0.43	0.29	113.0	0.71	281	Jungtier,Raubtier,frei_Wildbahn,Raubkatze,Artgenosse	--vs.--	Käfig,Tierpark,Tierpfleger,Zoo,Zürcher_Zoo	--> weak NEW
#
# for Eichhörnchen:
# lex_in_simple (% of words in lex) = 0.23333333333333334
# lex_lh = 85.5
# unknown_lh = 365
# lex_lh_perc = 0.1897891231964484
# unknown_lh_perc = 0.8102108768035516
# ### adding the WEAK Eichhörnchen to TEMPlex! ###
# Eichhörnchen:::8	0.23	0.19	85.5	0.81	365	Schildkröte,Fledermaus,Wildschwein,Katze,Affe	--vs.--	Igel,Krähe,Frosch,Eidechse,Hase	--> weak NEW
#
# for Säugetier:
# lex_in_simple (% of words in lex) = 0.23333333333333334
# lex_lh = 90.5
# unknown_lh = 321
# lex_lh_perc = 0.21992709599027946
# unknown_lh_perc = 0.7800729040097205
# ### adding the WEAK Säugetier to TEMPlex! ###
# Säugetier:::8	0.23	0.22	90.5	0.78	321	Reptil,Schimpanse,Tier,Artgenosse,Affe	--vs.--	Lebewesen,Tierart,Insekt,Menschenaffe,Vogelart	--> weak NEW
#
# for Weibchen:
# lex_in_simple (% of words in lex) = 0.43333333333333335
# lex_lh = 133.0
# unknown_lh = 234
# lex_lh_perc = 0.36239782016348776
# unknown_lh_perc = 0.6376021798365122
# ### adding the WEAK Weibchen to TEMPlex! ###
# Weibchen:::8	0.43	0.36	133.0	0.64	234	Männchen,Jungtier,Artgenosse,Säugetier,Tier	--vs.--	Jungvogel,Küken,Aufzucht,Larve,Gefieder	--> weak NEW
#
# for Wildtier:
# lex_in_simple (% of words in lex) = 0.36666666666666664
# lex_lh = 101.0
# unknown_lh = 307
# lex_lh_perc = 0.24754901960784315
# unknown_lh_perc = 0.7524509803921569
# ### adding the WEAK Wildtier to TEMPlex! ###
# Wildtier:::7	0.37	0.25	101.0	0.75	307	Tier,Raubtier,Wildschwein,frei_Wildbahn,Artgenosse	--vs.--	Reh,Nutztier,Tierart,Greifvogel,Luchs	--> weak NEW
#
# for wild_Tier:
# lex_in_simple (% of words in lex) = 0.5
# lex_lh = 155.5
# unknown_lh = 200
# lex_lh_perc = 0.43741209563994377
# unknown_lh_perc = 0.5625879043600562
# ### adding the WEAK wild_Tier to TEMPlex! ###
# wild_Tier:::7	0.50	0.44	155.5	0.56	200	Raubtier,Raubkatze,Affe,Tier,Wildtier	--vs.--	Elefant,Wildnis,Bestie,Kreatur,Krähe	--> weak NEW
#
# for Eidechse:
# lex_in_simple (% of words in lex) = 0.3333333333333333
# lex_lh = 108.0
# unknown_lh = 303
# lex_lh_perc = 0.26277372262773724
# unknown_lh_perc = 0.7372262773722628
# ### adding the WEAK Eidechse to TEMPlex! ###
# Eidechse:::7	0.33	0.26	108.0	0.74	303	Schildkröte,Reptil,Eichhörnchen,Fledermaus,Affe	--vs.--	Insekt,Frosch,Schnecke,Schmetterling,Vogel	--> weak NEW
#
# for Tierchen:
# lex_in_simple (% of words in lex) = 0.4
# lex_lh = 115.0
# unknown_lh = 280
# lex_lh_perc = 0.2911392405063291
# unknown_lh_perc = 0.7088607594936709
# ### adding the WEAK Tierchen to TEMPlex! ###
# Tierchen:::7	0.40	0.29	115.0	0.71	280	Reptil,Tier,Eichhörnchen,Schildkröte,Artgenosse	--vs.--	Insekt,Ameise,Schnecke,Spinne,Viech	--> weak NEW
#
# for Insekt:
# lex_in_simple (% of words in lex) = 0.23333333333333334
# lex_lh = 84.5
# unknown_lh = 341
# lex_lh_perc = 0.19858989424206816
# unknown_lh_perc = 0.8014101057579318
# ### adding the WEAK Insekt to TEMPlex! ###
# Insekt:::7	0.23	0.20	84.5	0.80	341	Reptil,Wespe,Säugetier,Fledermaus,Tierchen	--vs.--	Biene,Raup,Pflanze,Ameise,Mücke	--> weak NEW
#
# for Giraffe:
# lex_in_simple (% of words in lex) = 0.5666666666666667
# lex_lh = 193.5
# unknown_lh = 172
# lex_lh_perc = 0.5294117647058824
# unknown_lh_perc = 0.47058823529411764
# ##### adding Giraffe to lex! #####
# Giraffe:::6	0.57	0.53	193.5	0.47	172	Nashorn,Pinguin,Affe,Krokodil,Schildkröte	--vs.--	Elefant,Zebra,Büffel,Drache,Hase	--> very strong TO_ADD_IN
#
# for Zebra:
# lex_in_simple (% of words in lex) = 0.5666666666666667
# lex_lh = 179.0
# unknown_lh = 181
# lex_lh_perc = 0.49722222222222223
# unknown_lh_perc = 0.5027777777777778
# ### adding the WEAK Zebra to TEMPlex! ###
# Zebra:::6	0.57	0.50	179.0	0.50	181	Giraffe,Nashorn,Krokodil,Raubkatze,Affe	--vs.--	Elefant,Leopard,Büffel,Hase,Kamel	--> weak NEW
#
# for Zoo:
# lex_in_simple (% of words in lex) = 0.5333333333333333
# lex_lh = 119.5
# unknown_lh = 265
# lex_lh_perc = 0.3107932379713914
# unknown_lh_perc = 0.6892067620286085
# ### adding the WEAK Zoo to TEMPlex! ###
# Zoo:::6	0.53	0.31	119.5	0.69	265	Gehege,Jungtier,Gorilla,frei_Wildbahn,Affe	--vs.--	Zürcher_Zoo,Zoo_Zürich,Tierpark,Masoala-Halle,Elefant	--> weak NEW
#
# for Menschenaffe:
# lex_in_simple (% of words in lex) = 0.5333333333333333
# lex_lh = 188.0
# unknown_lh = 155
# lex_lh_perc = 0.5481049562682215
# unknown_lh_perc = 0.4518950437317784
# ##### adding Menschenaffe to lex! #####
# Menschenaffe:::6	0.53	0.55	188.0	0.45	155	Schimpanse,Gorilla,Säugetier,Affe,Tier	--vs.--	Tierart,Lebewesen,Elefant,Population,Zürcher_Zoo	--> very strong TO_ADD_IN
#
# for Tierart:
# lex_in_simple (% of words in lex) = 0.36666666666666664
# lex_lh = 90.5
# unknown_lh = 303
# lex_lh_perc = 0.22998729351969505
# unknown_lh_perc = 0.770012706480305
# ### adding the WEAK Tierart to TEMPlex! ###
# Tierart:::6	0.37	0.23	90.5	0.77	303	Säugetier,Tier,Insekt,Reptil,Wildtier	--vs.--	Vogelart,Population,Fischart,Pflanzenart,Lebensraum	--> weak NEW
#
# for Hase:
# lex_in_simple (% of words in lex) = 0.3
# lex_lh = 159.5
# unknown_lh = 282
# lex_lh_perc = 0.36126840317100795
# unknown_lh_perc = 0.638731596828992
# ### adding the WEAK Hase to TEMPlex! ###
# Hase:::6	0.30	0.36	159.5	0.64	282	Kaninchen,Wildschwein,Huhn,Eichhörnchen,Katze	--vs.--	Reh,Igel,Fuchs,Schnecke,Ente	--> weak NEW
#
# for Frosch:
# lex_in_simple (% of words in lex) = 0.4666666666666667
# lex_lh = 139.0
# unknown_lh = 237
# lex_lh_perc = 0.3696808510638298
# unknown_lh_perc = 0.6303191489361702
# ### adding the WEAK Frosch to TEMPlex! ###
# Frosch:::6	0.47	0.37	139.0	0.63	237	Insekt,Eichhörnchen,Schildkröte,Fledermaus,Eidechse	--vs.--	Amphibie,Kröte,Schnecke,Schmetterling,Igel	--> weak NEW
#
# for Elefant:
# lex_in_simple (% of words in lex) = 0.7666666666666667
# lex_lh = 232.5
# unknown_lh = 76
# lex_lh_perc = 0.7536466774716369
# unknown_lh_perc = 0.24635332252836303
# ##### adding Elefant to lex! #####
# Elefant:::6	0.77	0.75	232.5	0.25	76	Nashorn,Affe,Giraffe,Tier,Krokodil	--vs.--	Kamel,Zürcher_Zoo,Zoo_Zürich,Tierpark,Esel	--> very strong TO_ADD_IN
#
# for Wildkatze:
# lex_in_simple (% of words in lex) = 0.7
# lex_lh = 231.5
# unknown_lh = 110
# lex_lh_perc = 0.677891654465593
# unknown_lh_perc = 0.32210834553440704
# ##### adding Wildkatze to lex! #####
# Wildkatze:::6	0.70	0.68	231.5	0.32	110	Raubtier,Raubkatze,Artgenosse,frei_Wildbahn,Braunbär	--vs.--	Luchs,Luch,Reh,Jungvogel,Population	--> very strong TO_ADD_IN
#
# for Ratte:
# lex_in_simple (% of words in lex) = 0.4666666666666667
# lex_lh = 123.0
# unknown_lh = 264
# lex_lh_perc = 0.3178294573643411
# unknown_lh_perc = 0.6821705426356589
# ### adding the WEAK Ratte to TEMPlex! ###
# Ratte:::6	0.47	0.32	123.0	0.68	264	Affe,Artgenosse,Tier,Katze,Insekt	--vs.--	Maus,Nager,Ameise,Kakerlake,Parasit	--> weak NEW
#
# for Tierpark:
# lex_in_simple (% of words in lex) = 0.6
# lex_lh = 170.0
# unknown_lh = 202
# lex_lh_perc = 0.45698924731182794
# unknown_lh_perc = 0.543010752688172
# ### adding the WEAK Tierpark to TEMPlex! ###
# Tierpark:::5	0.60	0.46	170.0	0.54	202	Zoo,Gehege,Jungtier,Elefant,Wildtier	--vs.--	Wildpark,Zürcher_Zoo,Zoo_Zürich,Wildpark_Langenberg,Tierpfleger	--> weak NEW
#
# for Zürcher_Zoo:
# lex_in_simple (% of words in lex) = 0.6333333333333333
# lex_lh = 187.5
# unknown_lh = 189
# lex_lh_perc = 0.49800796812749004
# unknown_lh_perc = 0.50199203187251
# ### adding the WEAK Zürcher_Zoo to TEMPlex! ###
# Zürcher_Zoo:::5	0.63	0.50	187.5	0.50	189	Zoo,Tierpark,Gehege,Jungtier,Elefant	--vs.--	Zoo_Zürich,Masoala-Halle,Rübel,Wildpark,Tierpfleger	--> weak NEW
#
# for Zoo_Zürich:
# lex_in_simple (% of words in lex) = 0.6333333333333333
# lex_lh = 176.0
# unknown_lh = 173
# lex_lh_perc = 0.504297994269341
# unknown_lh_perc = 0.49570200573065903
# ##### adding Zoo_Zürich to lex! #####
# Zoo_Zürich:::5	0.63	0.50	176.0	0.50	173	Zürcher_Zoo,Zoo,Tierpark,Jungtier,Gehege	--vs.--	Masoala-Halle,Rübel,Wildpark_Langenberg,Wildpark,Tierpfleger	--> very strong TO_ADD_IN
#
# for Büffel:
# lex_in_simple (% of words in lex) = 0.4666666666666667
# lex_lh = 163.0
# unknown_lh = 232
# lex_lh_perc = 0.41265822784810124
# unknown_lh_perc = 0.5873417721518988
# ### adding the WEAK Büffel to TEMPlex! ###
# Büffel:::5	0.47	0.41	163.0	0.59	232	Elefant,Giraffe,Raubkatze,Affe,Raubtier	--vs.--	Ziege,Schaf,Schwein,Esel,Rind	--> weak NEW
#
# for Känguru:
# lex_in_simple (% of words in lex) = 0.7333333333333333
# lex_lh = 257.0
# unknown_lh = 64
# lex_lh_perc = 0.8006230529595015
# unknown_lh_perc = 0.19937694704049844
# ##### adding Känguru to lex! #####
# Känguru:::5	0.73	0.80	257.0	0.20	64	Schildkröte,Elefant,Krokodil,Papagei,Eichhörnchen	--vs.--	Reh,Hai,Kätzchen,Küken,Krähe	--> very strong TO_ADD_IN
#
# for Ziege:
# lex_in_simple (% of words in lex) = 0.23333333333333334
# lex_lh = 80.0
# unknown_lh = 366
# lex_lh_perc = 0.17937219730941703
# unknown_lh_perc = 0.820627802690583
# ### adding the WEAK Ziege to TEMPlex! ###
# Ziege:::5	0.23	0.18	80.0	0.82	366	Huhn,Kaninchen,Tier,Gans,Büffel	--vs.--	Schaf,Rind,Kuh,Schwein,Kalb	--> weak NEW
#
# for Greifvogel:
# lex_in_simple (% of words in lex) = 0.5333333333333333
# lex_lh = 154.0
# unknown_lh = 236
# lex_lh_perc = 0.39487179487179486
# unknown_lh_perc = 0.6051282051282051
# ### adding the WEAK Greifvogel to TEMPlex! ###
# Greifvogel:::5	0.53	0.39	154.0	0.61	236	Wildtier,Insekt,Fledermaus,Reptil,Tier	--vs.--	Vogel,Wasservogel,Jungvogel,Zugvogel,Vogelart	--> weak NEW
#
# for Kadaver:
# lex_in_simple (% of words in lex) = 0.43333333333333335
# lex_lh = 141.5
# unknown_lh = 249
# lex_lh_perc = 0.36235595390524966
# unknown_lh_perc = 0.6376440460947503
# ### adding the WEAK Kadaver to TEMPlex! ###
# Kadaver:::5	0.43	0.36	141.5	0.64	249	Tier,Jungtier,Artgenosse,Schildkröte,Raubtier	--vs.--	verenden,Kot,Schaf,Schwein,Futter	--> weak NEW
#
# for Taube:
# lex_in_simple (% of words in lex) = 0.6
# lex_lh = 149.5
# unknown_lh = 246
# lex_lh_perc = 0.3780025284450063
# unknown_lh_perc = 0.6219974715549936
# ### adding the WEAK Taube to TEMPlex! ###
# Taube:::5	0.60	0.38	149.5	0.62	246	Fledermaus,Katze,Schildkröte,Affe,Eichhörnchen	--vs.--	Spatz,Krähe,Eule,Ente,Vogel	--> weak NEW
#
# for Eule:
# lex_in_simple (% of words in lex) = 0.5666666666666667
# lex_lh = 170.0
# unknown_lh = 177
# lex_lh_perc = 0.4899135446685879
# unknown_lh_perc = 0.5100864553314121
# ### adding the WEAK Eule to TEMPlex! ###
# Eule:::5	0.57	0.49	170.0	0.51	177	Taube,Fledermaus,Eichhörnchen,Frosch,Schildkröte	--vs.--	Igel,Krähe,Amsel,Schmetterling,Vogel	--> weak NEW
#
# for tierisch:
# lex_in_simple (% of words in lex) = 0.3333333333333333
# lex_lh = 107.0
# unknown_lh = 290
# lex_lh_perc = 0.2695214105793451
# unknown_lh_perc = 0.7304785894206549
# ### adding the WEAK tierisch to TEMPlex! ###
# tierisch:::5	0.33	0.27	107.0	0.73	290	Affe,Tier,Artgenosse,Ratte,Säugetier	--vs.--	menschlich,Lebewesen,Maus,Nager,pflanzlich	--> weak NEW
#
# for Kamel:
# lex_in_simple (% of words in lex) = 0.4666666666666667
# lex_lh = 151.0
# unknown_lh = 243
# lex_lh_perc = 0.383248730964467
# unknown_lh_perc = 0.616751269035533
# ### adding the WEAK Kamel to TEMPlex! ###
# Kamel:::4	0.47	0.38	151.0	0.62	243	Elefant,Ziege,Affe,Giraffe,Papagei	--vs.--	Esel,Pferd,Pony,Kuh,Schwein	--> weak NEW
#
# for Reh:
# lex_in_simple (% of words in lex) = 0.4666666666666667
# lex_lh = 155.5
# unknown_lh = 246
# lex_lh_perc = 0.38729763387297633
# unknown_lh_perc = 0.6127023661270237
# ### adding the WEAK Reh to TEMPlex! ###
# Reh:::4	0.47	0.39	155.5	0.61	246	Wildschwein,Hirsch,Wildtier,Tier,Hase	--vs.--	Gämse,Luch,Jäger,Wildhüter,Schaf	--> weak NEW
#
# for Ente:
# lex_in_simple (% of words in lex) = 0.5333333333333333
# lex_lh = 192.0
# unknown_lh = 216
# lex_lh_perc = 0.47058823529411764
# unknown_lh_perc = 0.5294117647058824
# ### adding the WEAK Ente to TEMPlex! ###
# Ente:::4	0.53	0.47	192.0	0.53	216	Gans,Huhn,Kaninchen,Schildkröte,Katze	--vs.--	Fisch,Wasservogel,Federvieh,Schwein,Forelle	--> weak NEW
# for Krähe:
# lex_in_simple (% of words in lex) = 0.5666666666666667
# lex_lh = 176.5
# unknown_lh = 180
# lex_lh_perc = 0.4950911640953717
# unknown_lh_perc = 0.5049088359046283
# ### adding the WEAK Krähe to TEMPlex! ###
# Krähe:::4	0.57	0.50	176.5	0.50	180	Insekt,Eichhörnchen,Taube,Reh,Wildschwein	--vs.--	Vogel,Amsel,Rabe,Ameise,fressen	--> weak NEW
#
# for Schaf:
# lex_in_simple (% of words in lex) = 0.4
# lex_lh = 115.0
# unknown_lh = 306
# lex_lh_perc = 0.27315914489311166
# unknown_lh_perc = 0.7268408551068883
# ### adding the WEAK Schaf to TEMPlex! ###
# Schaf:::4	0.40	0.27	115.0	0.73	306	Ziege,Huhn,Tier,Kaninchen,Reh	--vs.--	Kuh,Rind,Schwein,Kalb,Geiss	--> weak NEW
#
# for Schnecke:
# lex_in_simple (% of words in lex) = 0.36666666666666664
# lex_lh = 107.0
# unknown_lh = 292
# lex_lh_perc = 0.2681704260651629
# unknown_lh_perc = 0.731829573934837
# ### adding the WEAK Schnecke to TEMPlex! ###
# Schnecke:::4	0.37	0.27	107.0	0.73	292	Insekt,Frosch,Tierchen,Schildkröte,Eidechse	--vs.--	Wurm,Ameise,fressen,Raup,Fisch	--> weak NEW
#
# for Maus:
# lex_in_simple (% of words in lex) = 0.26666666666666666
# lex_lh = 73.5
# unknown_lh = 318
# lex_lh_perc = 0.18773946360153257
# unknown_lh_perc = 0.8122605363984674
# ### adding the WEAK Maus to TEMPlex! ###
# Maus:::4	0.27	0.19	73.5	0.81	318	Ratte,Affe,Säugetier,Insekt,Artgenosse	--vs.--	Nager,Wurm,Protein,Ameise,Bakterie	--> weak NEW
#
# for Nager:
# lex_in_simple (% of words in lex) = 0.5666666666666667
# lex_lh = 175.0
# unknown_lh = 144
# lex_lh_perc = 0.54858934169279
# unknown_lh_perc = 0.45141065830721006
# ##### adding Nager to lex! #####
# Nager:::4	0.57	0.55	175.0	0.45	144	Maus,Ratte,Insekt,Tier,Säugetier	--vs.--	Ameise,Mücke,fressen,Raup,Schwein	--> very strong TO_ADD_IN
#
# for erlegen:
# lex_in_simple (% of words in lex) = 0.5333333333333333
# lex_lh = 179.5
# unknown_lh = 216
# lex_lh_perc = 0.4538558786346397
# unknown_lh_perc = 0.5461441213653603
# ### adding the WEAK erlegen to TEMPlex! ###
# erlegen:::3	0.53	0.45	179.5	0.55	216	Wildschwein,Raubtier,Reh,Braunbär,Wolf	--vs.--	Wildhüter,Jäger,Luch,Gämse,Wilderer	--> weak NEW
#
# for Luch:
# lex_in_simple (% of words in lex) = 0.5666666666666667
# lex_lh = 218.0
# unknown_lh = 193
# lex_lh_perc = 0.5304136253041363
# unknown_lh_perc = 0.46958637469586373
# ##### adding Luch to lex! #####
# Luch:::3	0.57	0.53	218.0	0.47	193	Braunbär,Wolf,Raubtier,Reh,Bartgeier	--vs.--	Luchs,Gämse,Wildhüter,M13,Jäger	--> very strong TO_ADD_IN
#
# for Igel:
# lex_in_simple (% of words in lex) = 0.6
# lex_lh = 200.0
# unknown_lh = 122
# lex_lh_perc = 0.6211180124223602
# unknown_lh_perc = 0.37888198757763975
# ##### adding Igel to lex! #####
# Igel:::3	0.60	0.62	200.0	0.38	122	Eichhörnchen,Hase,Reh,Frosch,Fledermaus	--vs.--	Kleintier,Fuchs,Meerschweinchen,Storch,Vogel	--> very strong TO_ADD_IN
#
# for Storch:
# lex_in_simple (% of words in lex) = 0.5
# lex_lh = 158.5
# unknown_lh = 225
# lex_lh_perc = 0.4132985658409387
# unknown_lh_perc = 0.5867014341590613
# ### adding the WEAK Storch to TEMPlex! ###
# Storch:::3	0.50	0.41	158.5	0.59	225	Fledermaus,Jungtier,Greifvogel,Taube,Bartgeier	--vs.--	Jungvogel,Vogel,Wasservogel,Zugvogel,Amsel	--> weak NEW
#
# for fressen:
# lex_in_simple (% of words in lex) = 0.4666666666666667
# lex_lh = 114.5
# unknown_lh = 263
# lex_lh_perc = 0.3033112582781457
# unknown_lh_perc = 0.6966887417218544
# ### adding the WEAK fressen to TEMPlex! ###
# fressen:::3	0.47	0.30	114.5	0.70	263	Schnecke,Insekt,Tier,Ratte,Krähe	--vs.--	Futter,ernähren,Wurm,füttern,verfüttern	--> weak NEW
#
# for Hai:
# lex_in_simple (% of words in lex) = 0.5333333333333333
# lex_lh = 158.0
# unknown_lh = 243
# lex_lh_perc = 0.3940149625935162
# unknown_lh_perc = 0.6059850374064838
# ### adding the WEAK Hai to TEMPlex! ###
# Hai:::3	0.53	0.39	158.0	0.61	243	Schildkröte,Krokodil,Pinguin,Wal,Reptil	--vs.--	Fisch,Meeressäuger,Delfin,Delphin,Tintenfisch	--> weak NEW
#
# for Käfig:
# lex_in_simple (% of words in lex) = 0.6333333333333333
# lex_lh = 209.5
# unknown_lh = 128
# lex_lh_perc = 0.6207407407407407
# unknown_lh_perc = 0.37925925925925924
# ##### adding Käfig to lex! #####
# Käfig:::3	0.63	0.62	209.5	0.38	128	Gehege,Affe,Kaninchen,Artgenosse,Tier	--vs.--	Aquarium,Meerschweinchen,Gitter,Hamster,Nest	--> very strong TO_ADD_IN
#
# for Spinne:
# lex_in_simple (% of words in lex) = 0.6333333333333333
# lex_lh = 178.0
# unknown_lh = 176
# lex_lh_perc = 0.5028248587570622
# unknown_lh_perc = 0.4971751412429379
# ##### adding Spinne to lex! #####
# Spinne:::3	0.63	0.50	178.0	0.50	176	Insekt,Schnecke,Tierchen,Fledermaus,Reptil	--vs.--	Ameise,Käfer,Wurm,Viech,Raup	--> very strong TO_ADD_IN
#
# for Haustier:
# lex_in_simple (% of words in lex) = 0.43333333333333335
# lex_lh = 129.0
# unknown_lh = 271
# lex_lh_perc = 0.3225
# unknown_lh_perc = 0.6775
# ### adding the WEAK Haustier to TEMPlex! ###
# Haustier:::3	0.43	0.32	129.0	0.68	271	Katze,Tier,Huhn,Kaninchen,Wildtier	--vs.--	Hund,Meerschweinchen,Vierbeiner,Büsi,Hamster	--> weak NEW
#
# for Ameise:
# lex_in_simple (% of words in lex) = 0.6
# lex_lh = 162.0
# unknown_lh = 199
# lex_lh_perc = 0.4487534626038781
# unknown_lh_perc = 0.5512465373961218
# ### adding the WEAK Ameise to TEMPlex! ###
# Ameise:::3	0.60	0.45	162.0	0.55	199	Insekt,Spinne,Ratte,Schnecke,Maus	--vs.--	Raup,Wurm,Biene,Kakerlake,Käfer	--> weak NEW
#
# for Hund:
# lex_in_simple (% of words in lex) = 0.16666666666666666
# lex_lh = 49.0
# unknown_lh = 374
# lex_lh_perc = 0.11583924349881797
# unknown_lh_perc = 0.8841607565011821
# ### adding the WEAK Hund to TEMPlex! ###
# Hund:::3	0.17	0.12	49.0	0.88	374	Katze,Tier,Haustier,Kaninchen,Schaf	--vs.--	Vierbeiner,Schäferhund,Hündin,Hundebesitzer,Hundehalter	--> weak NEW
#
# for Schwein:
# lex_in_simple (% of words in lex) = 0.36666666666666664
# lex_lh = 130.5
# unknown_lh = 280
# lex_lh_perc = 0.31790499390986604
# unknown_lh_perc = 0.682095006090134
# ### adding the WEAK Schwein to TEMPlex! ###
# Schwein:::3	0.37	0.32	130.5	0.68	280	Huhn,Ziege,Schaf,Kaninchen,Gans	--vs.--	Rind,Kalb,Kuh,schlachten,Lamm	--> weak NEW
#
# for Wilderer:
# lex_in_simple (% of words in lex) = 0.6
# lex_lh = 199.0
# unknown_lh = 162
# lex_lh_perc = 0.5512465373961218
# unknown_lh_perc = 0.4487534626038781
# ##### adding Wilderer to lex! #####
# Wilderer:::2	0.60	0.55	199.0	0.45	162	Nashorn,Raubtier,erlegen,Wildtier,Raubkatze	--vs.--	Wildhüter,Jäger,Nationalpark,Tierschützer,Luchs	--> very strong TO_ADD_IN
#
# for Esel:
# lex_in_simple (% of words in lex) = 0.4666666666666667
# lex_lh = 134.5
# unknown_lh = 250
# lex_lh_perc = 0.34980494148244473
# unknown_lh_perc = 0.6501950585175552
# ### adding the WEAK Esel to TEMPlex! ###
# Esel:::2	0.47	0.35	134.5	0.65	250	Ziege,Schaf,Kamel,Schwein,Huhn	--vs.--	Kuh,Maultier,Pony,Geiss,Hirte	--> weak NEW
#
# for Tiger:
# lex_in_simple (% of words in lex) = 0.36666666666666664
# lex_lh = 146.0
# unknown_lh = 262
# lex_lh_perc = 0.35784313725490197
# unknown_lh_perc = 0.6421568627450981
# ### adding the WEAK Tiger to TEMPlex! ###
# Tiger:::2	0.37	0.36	146.0	0.64	262	Löwe,Elefant,Raubkatze,Krokodil,Eisbär	--vs.--	SCL_Tiger,Lions,Leopard,Panther,Fribourg	--> weak NEW
#
# for Tierpfleger:
# lex_in_simple (% of words in lex) = 0.7333333333333333
# lex_lh = 198.0
# unknown_lh = 130
# lex_lh_perc = 0.6036585365853658
# unknown_lh_perc = 0.39634146341463417
# ##### adding Tierpfleger to lex! #####
# Tierpfleger:::2	0.73	0.60	198.0	0.40	130	Gehege,Jungtier,Zoo,Zürcher_Zoo,Zoo_Zürich	--vs.--	Tierarzt,Wildhüter,Wildpark,Pfleger,Veterinär	--> very strong TO_ADD_IN
#
# for ausgestopft:
# lex_in_simple (% of words in lex) = 0.5
# lex_lh = 186.0
# unknown_lh = 183
# lex_lh_perc = 0.5040650406504065
# unknown_lh_perc = 0.4959349593495935
# ##### adding ausgestopft to lex! #####
# ausgestopft:::2	0.50	0.50	186.0	0.50	183	Nashorn,Papagei,Eichhörnchen,Schildkröte,Hirsch	--vs.--	lebensgroß,Teddybär,putzig,bemalt,Puppe	--> very strong TO_ADD_IN
#
# for Gämse:
# lex_in_simple (% of words in lex) = 0.7333333333333333
# lex_lh = 263.5
# unknown_lh = 110
# lex_lh_perc = 0.7054886211512718
# unknown_lh_perc = 0.29451137884872824
# ##### adding Gämse to lex! #####
# Gämse:::2	0.73	0.71	263.5	0.29	110	Reh,Wildschwein,Luch,Hirsch,Steinbock	--vs.--	Luchs,Wildhüter,Murmeltier,Jäger,Schaf_reißen	--> very strong TO_ADD_IN
#
# for Luchs:
# lex_in_simple (% of words in lex) = 0.6333333333333333
# lex_lh = 261.5
# unknown_lh = 127
# lex_lh_perc = 0.6731016731016731
# unknown_lh_perc = 0.3268983268983269
# ##### adding Luchs to lex! #####
# Luchs:::2	0.63	0.67	261.5	0.33	127	Luch,Braunbär,Raubtier,Wildtier,Reh	--vs.--	Wildhüter,Population,Fischotter,Biber,Schaf_reißen	--> very strong TO_ADD_IN
#
# for Murmeltier:
# lex_in_simple (% of words in lex) = 0.8333333333333334
# lex_lh = 329.5
# unknown_lh = 40
# lex_lh_perc = 0.8917456021650879
# unknown_lh_perc = 0.10825439783491204
# ##### adding Murmeltier to lex! #####
# Murmeltier:::2	0.83	0.89	329.5	0.11	40	Eichhörnchen,Gämse,Luch,Bartgeier,Reh	--vs.--	Geiss,M13,Wildhüter,Jäger,Rentier	--> very strong TO_ADD_IN
#
# for Meerschweinchen:
# lex_in_simple (% of words in lex) = 0.6333333333333333
# lex_lh = 217.0
# unknown_lh = 136
# lex_lh_perc = 0.6147308781869688
# unknown_lh_perc = 0.38526912181303113
# ##### adding Meerschweinchen to lex! #####
# Meerschweinchen:::2	0.63	0.61	217.0	0.39	136	Katze,Kaninchen,Haustier,Huhn,Hund	--vs.--	Büsi,Hamster,Kleintier,Welpe,Ferkel	--> very strong TO_ADD_IN
#
# for Fisch:
# lex_in_simple (% of words in lex) = 0.3333333333333333
# lex_lh = 130.0
# unknown_lh = 291
# lex_lh_perc = 0.3087885985748218
# unknown_lh_perc = 0.6912114014251781
# ### adding the WEAK Fisch to TEMPlex! ###
# Fisch:::2	0.33	0.31	130.0	0.69	291	Lachs,Hecht,Ente,Schildkröte,Hai	--vs.--	Forelle,Felchen,Tintenfisch,Muschel,Thunfisch	--> weak NEW
#
# for Rüssel:
# lex_in_simple (% of words in lex) = 0.43333333333333335
# lex_lh = 113.5
# unknown_lh = 284
# lex_lh_perc = 0.28553459119496855
# unknown_lh_perc = 0.7144654088050314
# ### adding the WEAK Rüssel to TEMPlex! ###
# Rüssel:::2	0.43	0.29	113.5	0.71	284	Elefant,Krokodil,Tierchen,Affe,Schildkröte	--vs.--	Schnabel,Schnauze,Schwanz,streicheln,Maul	--> weak NEW
#
# for Lebewesen:
# lex_in_simple (% of words in lex) = 0.3333333333333333
# lex_lh = 94.0
# unknown_lh = 291
# lex_lh_perc = 0.24415584415584415
# unknown_lh_perc = 0.7558441558441559
# ### adding the WEAK Lebewesen to TEMPlex! ###
# Lebewesen:::2	0.33	0.24	94.0	0.76	291	Säugetier,Tier,Insekt,Tierart,Artgenosse	--vs.--	Organismus,Pflanze,Kreatur,Spezies,Mikroorganismus	--> weak NEW
#
# for Population:
# lex_in_simple (% of words in lex) = 0.36666666666666664
# lex_lh = 105.0
# unknown_lh = 289
# lex_lh_perc = 0.26649746192893403
# unknown_lh_perc = 0.733502538071066
# ### adding the WEAK Population to TEMPlex! ###
# Population:::2	0.37	0.27	105.0	0.73	289	Tierart,Säugetier,Luchs,Tier,frei_Wildbahn	--vs.--	Vogelart,Ökosystem,Bestand,Lebensraum,Fischart	--> weak NEW
#
# for Nutztier:
# lex_in_simple (% of words in lex) = 0.4
# lex_lh = 134.0
# unknown_lh = 239
# lex_lh_perc = 0.35924932975871315
# unknown_lh_perc = 0.6407506702412868
# ### adding the WEAK Nutztier to TEMPlex! ###
# Nutztier:::2	0.40	0.36	134.0	0.64	239	Tier,Wildtier,Schaf,Schwein,Ziege	--vs.--	Rind,Kuh,Geflügel,Fütterung,Tierhaltung	--> weak NEW
#
# for Aufzucht:
# lex_in_simple (% of words in lex) = 0.5666666666666667
# lex_lh = 138.5
# unknown_lh = 232
# lex_lh_perc = 0.3738191632928475
# unknown_lh_perc = 0.6261808367071525
# ### adding the WEAK Aufzucht to TEMPlex! ###
# Aufzucht:::2	0.57	0.37	138.5	0.63	232	Jungtier,Tier,Weibchen,Artgenosse,Männchen	--vs.--	Zucht,Fütterung,Jungvogel,Küken,züchten	--> weak NEW
#
# for Futter:
# lex_in_simple (% of words in lex) = 0.5
# lex_lh = 135.5
# unknown_lh = 232
# lex_lh_perc = 0.3687074829931973
# unknown_lh_perc = 0.6312925170068027
# ### adding the WEAK Futter to TEMPlex! ###
# Futter:::2	0.50	0.37	135.5	0.63	232	Tier,fressen,Huhn,Jungtier,Schwein	--vs.--	Nahrung,Fütterung,füttern,verfüttern,Rind	--> weak NEW
#
# for Vogel:
# lex_in_simple (% of words in lex) = 0.6
# lex_lh = 170.0
# unknown_lh = 186
# lex_lh_perc = 0.47752808988764045
# unknown_lh_perc = 0.5224719101123596
# ### adding the WEAK Vogel to TEMPlex! ###
# Vogel:::2	0.60	0.48	170.0	0.52	186	Insekt,Greifvogel,Storch,Fledermaus,Krähe	--vs.--	Amsel,Singvogel,Jungvogel,Wasservogel,Vogelart	--> weak NEW
#
# for Mücke:
# lex_in_simple (% of words in lex) = 0.4
# lex_lh = 110.0
# unknown_lh = 302
# lex_lh_perc = 0.2669902912621359
# unknown_lh_perc = 0.7330097087378641
# ### adding the WEAK Mücke to TEMPlex! ###
# Mücke:::2	0.40	0.27	110.0	0.73	302	Insekt,Wespe,Ameise,Ratte,Fledermaus	--vs.--	Parasit,Biene,Bakterie,Larve,Krankheitserreger	--> weak NEW
#
# for Singvogel:
# lex_in_simple (% of words in lex) = 0.6666666666666666
# lex_lh = 165.5
# unknown_lh = 167
# lex_lh_perc = 0.49774436090225566
# unknown_lh_perc = 0.5022556390977444
# ### adding the WEAK Singvogel to TEMPlex! ###
# Singvogel:::2	0.67	0.50	165.5	0.50	167	Vogel,Fledermaus,Insekt,Greifvogel,Männchen	--vs.--	Amsel,Zugvogel,Vogelart,Wasservogel,Jungvogel	--> weak NEW
#
# for Jungvogel:
# lex_in_simple (% of words in lex) = 0.6666666666666666
# lex_lh = 182.5
# unknown_lh = 141
# lex_lh_perc = 0.5641421947449768
# unknown_lh_perc = 0.43585780525502316
# ##### adding Jungvogel to lex! #####
# Jungvogel:::2	0.67	0.56	182.5	0.44	141	Jungtier,Weibchen,Storch,Männchen,Bartgeier	--vs.--	Nest,Wasservogel,Vogelart,Gefieder,Brut	--> very strong TO_ADD_IN
#
# for Elch:
# lex_in_simple (% of words in lex) = 0.8
# lex_lh = 295.0
# unknown_lh = 78
# lex_lh_perc = 0.7908847184986595
# unknown_lh_perc = 0.20911528150134048
# ##### adding Elch to lex! #####
# Elch:::1	0.80	0.79	295.0	0.21	78	Reh,Wildschwein,Hirsch,Braunbär,Raubtier	--vs.--	Rentier,Jäger,Biber,Rudel,Fuchs	--> very strong TO_ADD_IN
#
# for Wildhüter:
# lex_in_simple (% of words in lex) = 0.6666666666666666
# lex_lh = 268.0
# unknown_lh = 124
# lex_lh_perc = 0.6836734693877551
# unknown_lh_perc = 0.3163265306122449
# ##### adding Wildhüter to lex! #####
# Wildhüter:::1	0.67	0.68	268.0	0.32	124	Luch,Reh,Luchs,Wildschwein,erlegen	--vs.--	Jäger,Schaf_reißen,M13,Tierarzt,Förster	--> very strong TO_ADD_IN
#
# for Fuchs:
# lex_in_simple (% of words in lex) = 0.7333333333333333
# lex_lh = 223.5
# unknown_lh = 142
# lex_lh_perc = 0.6114911080711354
# unknown_lh_perc = 0.38850889192886456
# ##### adding Fuchs to lex! #####
# Fuchs:::1	0.73	0.61	223.5	0.39	142	Hase,Reh,Wolf,Wildschwein,Hirsch	--vs.--	Jäger,Wild,Dachs,Biber,Marder	--> very strong TO_ADD_IN
#
# for Stier:
# lex_in_simple (% of words in lex) = 0.5
# lex_lh = 149.5
# unknown_lh = 244
# lex_lh_perc = 0.3799237611181703
# unknown_lh_perc = 0.6200762388818297
# ### adding the WEAK Stier to TEMPlex! ###
# Stier:::1	0.50	0.38	149.5	0.62	244	Schaf,Steinbock,Ziege,Schwein,Esel	--vs.--	Kuh,Kalb,Muni,Rind,Geiss	--> weak NEW
#
# for Widder:
# lex_in_simple (% of words in lex) = 0.2
# lex_lh = 93.5
# unknown_lh = 359
# lex_lh_perc = 0.20662983425414364
# unknown_lh_perc = 0.7933701657458564
# ...
# lex_in_simple (% of words in lex) = 0.7666666666666667
# lex_lh = 380.5
# unknown_lh = 71
# lex_lh_perc = 0.8427464008859358
# unknown_lh_perc = 0.15725359911406422
# ##### adding Herd to lex! #####
# Herd:::3	0.77	0.84	380.5	0.16	71	Rind,Stall,Kalb,Ziege,Schaf	--vs.--	Küche,Pfanne,kochen,Teller,zubereiten	--> very strong TO_ADD_IN
#
# for Büsi:
# lex_in_simple (% of words in lex) = 0.5333333333333333
# lex_lh = 190.0
# unknown_lh = 250
# lex_lh_perc = 0.4318181818181818
# unknown_lh_perc = 0.5681818181818182
# ### adding the WEAK Büsi to TEMPlex! ###
# Büsi:::3	0.53	0.43	190.0	0.57	250	Katze,Hund,Meerschweinchen,Haustier,Tier	--vs.--	Hündin,Kätzchen,Frauchen,Herrchen,Tierheim	--> weak NEW
#
# for Tierhalter:
# lex_in_simple (% of words in lex) = 0.43333333333333335
# lex_lh = 166.5
# unknown_lh = 266
# lex_lh_perc = 0.38497109826589593
# unknown_lh_perc = 0.6150289017341041
# ### adding the WEAK Tierhalter to TEMPlex! ###
# Tierhalter:::3	0.43	0.38	166.5	0.62	266	Tier,Nutztier,Züchter,Vierbeiner,Hund	--vs.--	Hundehalter,Hundebesitzer,Veterinäramt,Tierarzt,Halter	--> weak NEW
#
# for Ochse:
# lex_in_simple (% of words in lex) = 0.6
# lex_lh = 336
# unknown_lh = 129
# lex_lh_perc = 0.7225806451612903
# unknown_lh_perc = 0.27741935483870966
# ##### adding Ochse to lex! #####
# Ochse:::2	0.60	0.72	336	0.28	129	Esel,Kuh,Hirsch,Schwein,Ziege	--vs.--	Gasthaus,Gasthof,Rössli,Wirtshaus,Restaurant	--> very strong TO_ADD_IN
# for Welpe:
# lex_in_simple (% of words in lex) = 0.6666666666666666
# lex_lh = 276.5
# unknown_lh = 143
# lex_lh_perc = 0.6591179976162098
# unknown_lh_perc = 0.34088200238379024
# ##### adding Welpe to lex! #####
# Welpe:::2	0.67	0.66	276.5	0.34	143	Hund,Jungtier,Katze,Tier,Büsi	--vs.--	Hündin,Kätzchen,Tierheim,Schäferhund,Baby	--> very strong TO_ADD_IN
#
# for Tierarzt:
# lex_in_simple (% of words in lex) = 0.4666666666666667
# lex_lh = 164.5
# unknown_lh = 250
# lex_lh_perc = 0.3968636911942099
# unknown_lh_perc = 0.6031363088057901
# ### adding the WEAK Tierarzt to TEMPlex! ###
# Tierarzt:::2	0.47	0.40	164.5	0.60	250	Tierhalter,Hund,Tierpfleger,Tier,Vierbeiner	--vs.--	Veterinär,Tierärztin,Veterinäramt,einschläfern,Tierheim	--> weak NEW
#
# for Hündin:
# lex_in_simple (% of words in lex) = 0.3
# lex_lh = 123.0
# unknown_lh = 290
# lex_lh_perc = 0.29782082324455206
# unknown_lh_perc = 0.7021791767554479
# ### adding the WEAK Hündin to TEMPlex! ###
# Hündin:::2	0.30	0.30	123.0	0.70	290	Hund,Büsi,Katze,Vierbeiner,Welpe	--vs.--	Herrchen,Schäferhund,Frauchen,Hündchen,Labrador	--> weak NEW
#
# for verenden:
# lex_in_simple (% of words in lex) = 0.8333333333333334
# lex_lh = 392.0
# unknown_lh = 61
# lex_lh_perc = 0.8653421633554084
# unknown_lh_perc = 0.1346578366445916
# ##### adding verenden to lex! #####
# verenden:::2	0.83	0.87	392.0	0.13	61	Kadaver,Tier,erlegen,Wasservogel,Ente	--vs.--	ertrinken,einschläfern,Wildvogel,verhungern,fangen	--> very strong TO_ADD_IN
#
# for Blauzungenkrankheit:
# lex_in_simple (% of words in lex) = 0.2
# lex_lh = 49.0
# unknown_lh = 403
# lex_lh_perc = 0.1084070796460177
# unknown_lh_perc = 0.8915929203539823
# ### adding the WEAK Blauzungenkrankheit to TEMPlex! ###
# Blauzungenkrankheit:::2	0.20	0.11	49.0	0.89	403	Geflügel,Nutztier,Rind,Ziege,Schaf	--vs.--	Vogelgrippe,Impfung,Wildvogel,impfen,Masern	--> weak NEW
#
# for Henne:
# lex_in_simple (% of words in lex) = 0.9
# lex_lh = 425
# unknown_lh = 40
# lex_lh_perc = 0.9139784946236559
# unknown_lh_perc = 0.08602150537634409
# ##### adding Henne to lex! #####
# Henne:::2	0.90	0.91	425	0.09	40	Huhn,Gans,Schwein,Kuh,Kaninchen	--vs.--	Hahn,Ei,Nest	--> very strong TO_ADD_IN
#
# for Tiger:
# lex_in_simple (% of words in lex) = 0.4
# lex_lh = 211.5
# unknown_lh = 245
# lex_lh_perc = 0.4633077765607886
# unknown_lh_perc = 0.5366922234392114
# ### adding the WEAK Tiger to TEMPlex! ###
# Tiger:::1	0.40	0.46	211.5	0.54	245	Löwe,Elefant,Raubkatze,Krokodil,Eisbär	--vs.--	SCL_Tiger,Lions,Leopard,Panther,Fribourg	--> weak NEW
#
# for grasen:
# lex_in_simple (% of words in lex) = 0.5
# lex_lh = 258.5
# unknown_lh = 192
# lex_lh_perc = 0.5738068812430632
# unknown_lh_perc = 0.4261931187569367
# ##### adding grasen to lex! #####
# grasen:::1	0.50	0.57	258.5	0.43	192	weiden,Weide,Ziege,Schaf,Kuh	--vs.--	Wiese,Gras,traben,Bauernhof,Waldrand	--> very strong TO_ADD_IN
#
# for Fell:
# lex_in_simple (% of words in lex) = 0.3333333333333333
# lex_lh = 150
# unknown_lh = 315
# lex_lh_perc = 0.3225806451612903
# unknown_lh_perc = 0.6774193548387096
# ### adding the WEAK Fell to TEMPlex! ###
# Fell:::1	0.33	0.32	150	0.68	315	Gefieder,Futter,Rind,Ziege,Hase	--vs.--	Pelz,Pfote,Wolle,Schwanz,Haut	--> weak NEW
#
# for Kätzchen:
# lex_in_simple (% of words in lex) = 0.7333333333333333
# lex_lh = 288.0
# unknown_lh = 140
# lex_lh_perc = 0.6728971962616822
# unknown_lh_perc = 0.32710280373831774
# ##### adding Kätzchen to lex! #####
# Kätzchen:::1	0.73	0.67	288.0	0.33	140	Katze,Büsi,Welpe,Hündin,Eichhörnchen	--vs.--	Kater,Hündchen,herzig,Dackel,niedlich	--> very strong TO_ADD_IN
#
# for Schäferhund:
# lex_in_simple (% of words in lex) = 0.3
# lex_lh = 94.5
# unknown_lh = 319
# lex_lh_perc = 0.22853688029020555
# unknown_lh_perc = 0.7714631197097944
# ### adding the WEAK Schäferhund to TEMPlex! ###
# Schäferhund:::1	0.30	0.23	94.5	0.77	319	Hund,Hündin,Vierbeiner,Katze,Büsi	--vs.--	Rottweiler,Kampfhund,Dackel,Pitbulls,Pitbull	--> weak NEW
#
# for Fisch:
# lex_in_simple (% of words in lex) = 0.43333333333333335
# lex_lh = 197
# unknown_lh = 268
# lex_lh_perc = 0.4236559139784946
# unknown_lh_perc = 0.5763440860215053
# ### adding the WEAK Fisch to TEMPlex! ###
# Fisch:::1	0.43	0.42	197	0.58	268	Lachs,Hecht,Ente,Schildkröte,Hai	--vs.--	Forelle,Felchen,Tintenfisch,Muschel,Thunfisch	--> weak NEW
#
# for Maus:
# lex_in_simple (% of words in lex) = 0.5
# lex_lh = 249.0
# unknown_lh = 210
# lex_lh_perc = 0.5424836601307189
# unknown_lh_perc = 0.45751633986928103
# ##### adding Maus to lex! #####
# Maus:::1	0.50	0.54	249.0	0.46	210	Ratte,Nager,Affe,Wurm,Ameise	--vs.--	Protein,Bakterie,Gen,Nervenzelle,Krebszelle	--> very strong TO_ADD_IN
#
# for Schaf_reißen:
# lex_in_simple (% of words in lex) = 0.6666666666666666
# lex_lh = 346
# unknown_lh = 119
# lex_lh_perc = 0.7440860215053764
# unknown_lh_perc = 0.25591397849462366
# ##### adding Schaf_reißen to lex! #####
# Schaf_reißen:::1	0.67	0.74	346	0.26	119	Braunbär,Wolf,Wildhüter,Raubtier,Luch	--vs.--	M13,Unterengadin,Münstertal,Abschuss,Goms	--> very strong TO_ADD_IN
#
# for Biene:
# lex_in_simple (% of words in lex) = 0.5333333333333333
# lex_lh = 253.5
# unknown_lh = 198
# lex_lh_perc = 0.5614617940199336
# unknown_lh_perc = 0.43853820598006643
# ##### adding Biene to lex! #####
# Biene:::1	0.53	0.56	253.5	0.44	198	Insekt,Wespe,Pflanze,Ameise,Mücke	--vs.--	Bienenvolk,Imker,Polle,Schädling,Bienenstock	--> very strong TO_ADD_IN
#
# for Zucht:
# lex_in_simple (% of words in lex) = 0.8
# lex_lh = 331.5
# unknown_lh = 101
# lex_lh_perc = 0.7664739884393064
# unknown_lh_perc = 0.23352601156069364
# ##### adding Zucht to lex! #####
# Zucht:::1	0.80	0.77	331.5	0.23	101	Züchter,züchten,Aufzucht,Tier,artgerecht	--vs.--	Züchtung,Tierhaltung,Rasse,Hengst,Stute	--> very strong TO_ADD_IN
#
# for Fleisch:
# lex_in_simple (% of words in lex) = 0.03333333333333333
# lex_lh = 1
# unknown_lh = 464
# lex_lh_perc = 0.002150537634408602
# unknown_lh_perc = 0.9978494623655914
# Fleisch:::1	0.03	0.00	1	1.00	464	Lachs	--vs.--	Rindfleisch,Käse,Gemüse,Schweinefleisch,Kalbfleisch	--> not decidable
#
# for Tierhaltung:
# lex_in_simple (% of words in lex) = 0.4666666666666667
# lex_lh = 207.5
# unknown_lh = 229
# lex_lh_perc = 0.4753722794959908
# unknown_lh_perc = 0.5246277205040092
# ### adding the WEAK Tierhaltung to TEMPlex! ###
# Tierhaltung:::1	0.47	0.48	207.5	0.52	229	artgerecht,Nutztier,Fütterung,Tierhalter,Zucht	--vs.--	Tierschutz,Landwirtschaft,Tierschutzgesetz,landwirtschaftlich,Direktzahlung	--> weak NEW
#
# for Züchtung:
# lex_in_simple (% of words in lex) = 0.26666666666666666
# lex_lh = 108.5
# unknown_lh = 331
# lex_lh_perc = 0.24687144482366324
# unknown_lh_perc = 0.7531285551763367
# ### adding the WEAK Züchtung to TEMPlex! ###
# Züchtung:::1	0.27	0.25	108.5	0.75	331	Pflanze,züchten,Zucht,Züchter,Rind	--vs.--	Sorte,anpflanzen,Same,Obstbaum,Gewächs	--> weak NEW
#
# for Pflanze:
# lex_in_simple (% of words in lex) = 0.23333333333333334
# lex_lh = 96.0
# unknown_lh = 355
# lex_lh_perc = 0.21286031042128603
# unknown_lh_perc = 0.7871396895787139
# ### adding the WEAK Pflanze to TEMPlex! ###
# Pflanze:::1	0.23	0.21	96.0	0.79	355	Insekt,Biene,Tier,Lebewesen,Züchtung	--vs.--	Same,Orchidee,Strauch,Staude,Schädling	--> weak NEW
#
# for Truthahn:
# lex_in_simple (% of words in lex) = 0.5666666666666667
# lex_lh = 303.0
# unknown_lh = 153
# lex_lh_perc = 0.6644736842105263
# unknown_lh_perc = 0.3355263157894737
# ##### adding Truthahn to lex! #####
# Truthahn:::1	0.57	0.66	303.0	0.34	153	Huhn,Schwein,Gans,Ente,Kaninchen	--vs.--	verspeisen,Steak,verzehren,Poulet,Auster	--> very strong TO_ADD_IN
# ... done in 0.429s.
# ------------------------------------------------------------
# ADDED to LEX in this run:
#
# {'Schwein', 'Vieh', 'Futter', 'füttern', 'Maultier', 'Schafherde', 'Welpe', 'Kätzchen', 'Maus', 'verenden', 'Federvieh', 'Rentier', 'schlachten', 'Schaf_reißen', 'Schaf', 'grasen', 'Kalb', 'Kuh', 'verfüttern', 'Fohlen', 'Lama', 'Ochse', 'Fütterung', 'Biene', 'Ziege', 'Stall', 'Lamm', 'Tierart', 'Herd', 'Rind', 'Geiss', 'Henne', 'Stier', 'Ferkel', 'Sau', 'züchten', 'weiden', 'Esel', 'Truthahn', 'Zucht'}
# ............................................................
# ADDED to WEAK-LEX in this run:
#
# {'Tierhalter', 'Hündin', 'Züchtung', 'Pflanze', 'Tiger', 'Hirte', 'Weide', 'Tierhaltung', 'Geflügel', 'Hund', 'Fisch', 'Pferd', 'Vierbeiner', 'Büsi', 'Schäferhund', 'Blauzungenkrankheit', 'Tierarzt', 'Fell', 'Züchter', 'Pony'}
# ------------------------------------------------------------
# ------------------------------------------------------------
# ADDED to LEX in the 3 recurrent run(s):
#
# {'Maultier', 'Ameise', 'ausgestopft', 'Schafherde', 'Känguru', 'Kätzchen', 'Jungtier', 'Eichhörnchen', 'verenden', 'Pinguin', 'Nager', 'Igel', 'grasen', 'Kleintier', 'Nashorn', 'Kalb', 'erlegen', 'Kamel', 'Lama', 'Raubkatze', 'Wildhüter', 'Stier', 'Tier', 'Frosch', 'Meerschweinchen', 'Wildkatze', 'Tierreich', 'Spinne', 'Käfer', 'Truthahn', 'Biber', 'Hase', 'Elefant', 'Vieh', 'Insekt', 'Welpe', 'Reh', 'Männchen', 'Rudel', 'schlachten', 'artgerecht', 'frei_Wildbahn', 'Larve', 'fressen', 'Schnecke', 'Hai', 'verfüttern', 'Murmeltier', 'Papagei', 'Haustier', 'Wilderer', 'Herd', 'Zoo_Zürich', 'Henne', 'Amsel', 'Ferkel', 'Käfig', 'Sau', 'Gehege', 'Schmetterling', 'Esel', 'Taube', 'Schwein', 'Futter', 'Ratte', 'Weibchen', 'Amphibie', 'füttern', 'Maus', 'wild_Tier', 'Viech', 'Katze', 'Küken', 'Schaf', 'Storch', 'Luch', 'Wurm', 'Hamster', 'Biene', 'Eidechse', 'Fütterung', 'Ziege', 'Stall', 'Jungvogel', 'Greifvogel', 'Eule', 'Raup', 'Tierart', 'Vogel', 'Mücke', 'Geiss', 'Rind', 'Singvogel', 'Nutztier', 'Säugetier', 'Luchs', 'Raubtier', 'züchten', 'weiden', 'Zucht', 'Menschenaffe', 'Tierchen', 'Krokodil', 'Reptil', 'Ente', 'Tierpfleger', 'Tierpark', 'Federvieh', 'Rentier', 'Fuchs', 'Schaf_reißen', 'Affe', 'Meeressäuger', 'Zebra', 'Wildtier', 'tierisch', 'Kuh', 'Fohlen', 'Ochse', 'Elch', 'Lamm', 'Krähe', 'Zürcher_Zoo', 'Büffel', 'Aufzucht', 'Kadaver', 'Wasservogel', 'Artgenosse', 'Zoo', 'Qualle', 'Gefieder', 'Giraffe', 'Gämse'}
# ............................................................
# ADDED to WEAK-LEX in the 3 recurrent run(s):
#
# ['Affe', 'Ameise', 'Aquarium', 'Artgenosse', 'Aufzucht', 'Biene', 'Blauzungenkrankheit', 'Büffel', 'Büsi', 'Dinosaurier', 'Drache', 'Eichhörnchen', 'Eidechse', 'Ente', 'Esel', 'Eule', 'Fell', 'Fisch', 'Frosch', 'Futter', 'Geflügel', 'Gehege', 'Greifvogel', 'Hai', 'Hase', 'Haustier', 'Hirte', 'Hund', 'Hündin', 'Insekt', 'Jungtier', 'Kadaver', 'Kamel', 'Katze', 'Krokodil', 'Krähe', 'Kuh', 'Lebensraum', 'Lebewesen', 'Maus', 'Männchen', 'Mücke', 'Nashorn', 'Nutztier', 'Papagei', 'Pferd', 'Pflanze', 'Pinguin', 'Pony', 'Population', 'Ratte', 'Raubkatze', 'Raubtier', 'Reh', 'Reptil', 'Rind', 'Rüssel', 'Saurier', 'Schaf', 'Schnecke', 'Schwein', 'Schäferhund', 'Singvogel', 'Stier', 'Storch', 'Säugetier', 'Taube', 'Tier', 'Tierart', 'Tierarzt', 'Tierchen', 'Tierhalter', 'Tierhaltung', 'Tierpark', 'Tierwelt', 'Tiger', 'Versuchstier', 'Vierbeiner', 'Vogel', 'Vogelart', 'Weibchen', 'Weide', 'Widder', 'Wildtier', 'Wurm', 'Zebra', 'Ziege', 'Zoo', 'Züchter', 'Züchtung', 'Zürcher_Zoo', 'erlegen', 'frei_Wildbahn', 'fressen', 'tierisch', 'wild_Tier']
# ------------------------------------------------------------
#
# New entries (respective to the given lexicon):
# overall 133 new STRONG entries.
# 128 words and 5 bigrams.
#
# ************************************************************
# ****************************** Lexicon status: NEW_STRONGs ******************************
# Affe		NEW_STRONG
# Ameise		NEW_STRONG
# Amphibie		NEW_STRONG
# Amsel		NEW_STRONG
# Artgenosse		NEW_STRONG
# Aufzucht		NEW_STRONG
# Biber		NEW_STRONG
# Biene		NEW_STRONG
# Büffel		NEW_STRONG
# Eichhörnchen		NEW_STRONG
# Eidechse		NEW_STRONG
# Elch		NEW_STRONG
# Elefant		NEW_STRONG
# Ente		NEW_STRONG
# Esel		NEW_STRONG
# Eule		NEW_STRONG
# Federvieh		NEW_STRONG
# Ferkel		NEW_STRONG
# Fohlen		NEW_STRONG
# Frosch		NEW_STRONG
# Fuchs		NEW_STRONG
# Futter		NEW_STRONG
# Fütterung		NEW_STRONG
# Gefieder		NEW_STRONG
# Gehege		NEW_STRONG
# Geiss		NEW_STRONG
# Giraffe		NEW_STRONG
# Greifvogel		NEW_STRONG
# Gämse		NEW_STRONG
# Hai		NEW_STRONG
# Hamster		NEW_STRONG
# Hase		NEW_STRONG
# Haustier		NEW_STRONG
# Henne		NEW_STRONG
# Herd		NEW_STRONG
# Igel		NEW_STRONG
# Insekt		NEW_STRONG
# Jungtier		NEW_STRONG
# Jungvogel		NEW_STRONG
# Kadaver		NEW_STRONG
# Kalb		NEW_STRONG
# Kamel		NEW_STRONG
# Katze		NEW_STRONG
# Kleintier		NEW_STRONG
# Krokodil		NEW_STRONG
# Krähe		NEW_STRONG
# Kuh		NEW_STRONG
# Käfer		NEW_STRONG
# Käfig		NEW_STRONG
# Känguru		NEW_STRONG
# Kätzchen		NEW_STRONG
# Küken		NEW_STRONG
# Lama		NEW_STRONG
# Lamm		NEW_STRONG
# Larve		NEW_STRONG
# Luch		NEW_STRONG
# Luchs		NEW_STRONG
# Maultier		NEW_STRONG
# Maus		NEW_STRONG
# Meeressäuger		NEW_STRONG
# Meerschweinchen		NEW_STRONG
# Menschenaffe		NEW_STRONG
# Murmeltier		NEW_STRONG
# Männchen		NEW_STRONG
# Mücke		NEW_STRONG
# Nager		NEW_STRONG
# Nashorn		NEW_STRONG
# Nutztier		NEW_STRONG
# Ochse		NEW_STRONG
# Papagei		NEW_STRONG
# Pinguin		NEW_STRONG
# Qualle		NEW_STRONG
# Ratte		NEW_STRONG
# Raubkatze		NEW_STRONG
# Raubtier		NEW_STRONG
# Raup		NEW_STRONG
# Reh		NEW_STRONG
# Rentier		NEW_STRONG
# Reptil		NEW_STRONG
# Rind		NEW_STRONG
# Rudel		NEW_STRONG
# Sau		NEW_STRONG
# Schaf		NEW_STRONG
# Schafherde		NEW_STRONG
# Schmetterling		NEW_STRONG
# Schnecke		NEW_STRONG
# Schwein		NEW_STRONG
# Singvogel		NEW_STRONG
# Spinne		NEW_STRONG
# Stall		NEW_STRONG
# Stier		NEW_STRONG
# Storch		NEW_STRONG
# Säugetier		NEW_STRONG
# Taube		NEW_STRONG
# Tier		NEW_STRONG
# Tierart		NEW_STRONG
# Tierchen		NEW_STRONG
# Tierpark		NEW_STRONG
# Tierpfleger		NEW_STRONG
# Tierreich		NEW_STRONG
# Truthahn		NEW_STRONG
# Viech		NEW_STRONG
# Vieh		NEW_STRONG
# Vogel		NEW_STRONG
# Wasservogel		NEW_STRONG
# Weibchen		NEW_STRONG
# Welpe		NEW_STRONG
# Wilderer		NEW_STRONG
# Wildhüter		NEW_STRONG
# Wildkatze		NEW_STRONG
# Wildtier		NEW_STRONG
# Wurm		NEW_STRONG
# Zebra		NEW_STRONG
# Ziege		NEW_STRONG
# Zoo		NEW_STRONG
# Zucht		NEW_STRONG
# artgerecht		NEW_STRONG
# ausgestopft		NEW_STRONG
# erlegen		NEW_STRONG
# fressen		NEW_STRONG
# füttern		NEW_STRONG
# grasen		NEW_STRONG
# schlachten		NEW_STRONG
# tierisch		NEW_STRONG
# verenden		NEW_STRONG
# verfüttern		NEW_STRONG
# weiden		NEW_STRONG
# züchten		NEW_STRONG
# ------------------------------------------------------------
# Schaf_reißen		NEW_STRONG
# Zoo_Zürich		NEW_STRONG
# Zürcher_Zoo		NEW_STRONG
# frei_Wildbahn		NEW_STRONG
# wild_Tier		NEW_STRONG
# ************************************************************
# overall 32 new weak entries
# ****************************** NEW_WEAKs ******************************
# Tierhalter		NEW_WEAK
# Rüssel		NEW_WEAK
# Hündin		NEW_WEAK
# Züchtung		NEW_WEAK
# Saurier		NEW_WEAK
# Widder		NEW_WEAK
# Versuchstier		NEW_WEAK
# Pflanze		NEW_WEAK
# Tiger		NEW_WEAK
# Weide		NEW_WEAK
# Hirte		NEW_WEAK
# Tierhaltung		NEW_WEAK
# Geflügel		NEW_WEAK
# Aquarium		NEW_WEAK
# Vogelart		NEW_WEAK
# Hund		NEW_WEAK
# Fisch		NEW_WEAK
# Pferd		NEW_WEAK
# Vierbeiner		NEW_WEAK
# Büsi		NEW_WEAK
# Tierwelt		NEW_WEAK
# Dinosaurier		NEW_WEAK
# Schäferhund		NEW_WEAK
# Blauzungenkrankheit		NEW_WEAK
# Lebensraum		NEW_WEAK
# Tierarzt		NEW_WEAK
# Fell		NEW_WEAK
# Drache		NEW_WEAK
# Züchter		NEW_WEAK
# Lebewesen		NEW_WEAK
# Population		NEW_WEAK
# Pony		NEW_WEAK

# %%
my_expander.write_out(target_filename="tiere_not_so_minimal.txt")
# Out:
# checking targetfolder
